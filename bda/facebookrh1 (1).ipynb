# %%
import pandas as pd

# %%
df=pd.read_csv("dataset_Facebook.csv",sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df1=df[["Type","Category","Post Month","Post Weekday","Post Hour"]]

# %%
df1
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour
# 0     Photo         2          12             4          3
# 1    Status         2          12             3         10
# 2     Photo         3          12             3          3
# 3     Photo         2          12             2         10
# 4     Photo         2          12             2          3
# ..      ...       ...         ...           ...        ...
# 495   Photo         3           1             7          2
# 496   Photo         2           1             5          8
# 497   Photo         1           1             5          2
# 498   Photo         3           1             4         11
# 499   Photo         2           1             4          4
#
# [500 rows x 5 columns]

# %%
df2 = df[['Category','Paid','Post Weekday']]
df2
# Out:
#      Category  Paid  Post Weekday
# 0           2   0.0             4
# 1           2   0.0             3
# 2           3   0.0             3
# 3           2   1.0             2
# 4           2   0.0             2
# ..        ...   ...           ...
# 495         3   0.0             7
# 496         2   0.0             5
# 497         1   0.0             5
# 498         3   0.0             4
# 499         2   NaN             4
#
# [500 rows x 3 columns]

# %%
sample=df.loc[10:50,["Type","Post Month"]]
sample
# Out:
#       Type  Post Month
# 10  Status          12
# 11   Photo          12
# 12   Photo          12
# 13   Photo          12
# 14   Photo          12
# 15  Status          12
# 16   Photo          12
# 17   Photo          12
# 18  Status          12
# 19   Photo          12
# 20   Photo          12
# 21   Photo          12
# 22    Link          12
# 23   Photo          12
# 24  Status          12
# 25  Status          12
# 26  Status          12
# 27   Photo          12
# 28   Photo          12
# 29   Video          12
# 30   Photo          12
# 31   Photo          12
# 32   Photo          12
# 33   Photo          12
# 34   Photo          12
# 35   Photo          12
# 36   Photo          12
# 37   Photo          12
# 38  Status          12
# 39   Photo          12
# 40  Status          12
# 41    Link          12
# 42   Photo          12
# 43    Link          12
# 44   Photo          12
# 45    Link          12
# 46  Status          12
# 47    Link          12
# 48   Photo          12
# ...

# %%
sample2=df.iloc[10:20,2:5]

# %%
sample2
# Out:
#     Category  Post Month  Post Weekday
# 10         2          12             5
# 11         2          12             5
# 12         2          12             5
# 13         2          12             5
# 14         2          12             4
# 15         2          12             3
# 16         3          12             3
# 17         1          12             2
# 18         3          12             2
# 19         3          12             1

# %%
merge=pd.concat([df1,df2])

# %%
merge
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid
# 0     Photo         2        12.0             4        3.0   NaN
# 1    Status         2        12.0             3       10.0   NaN
# 2     Photo         3        12.0             3        3.0   NaN
# 3     Photo         2        12.0             2       10.0   NaN
# 4     Photo         2        12.0             2        3.0   NaN
# ..      ...       ...         ...           ...        ...   ...
# 495     NaN         3         NaN             7        NaN   0.0
# 496     NaN         2         NaN             5        NaN   0.0
# 497     NaN         1         NaN             5        NaN   0.0
# 498     NaN         3         NaN             4        NaN   0.0
# 499     NaN         2         NaN             4        NaN   NaN
#
# [1000 rows x 6 columns]

# %%
sorted=df.sort_values(by='like',ascending=False)

# %%
sorted
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 76             137893  Photo         1          11             3          2
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
sorted= df.sort_values(by='like', ascending=True)
sorted
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 21             138414  Photo         1          12             7         10
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
transposed=df.head().transpose()

# %%
transposed
# Out:
#                                                          0       1       2  \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
new_df=pd.melt(df,id_vars='Post Month',value_vars='like')

# %%
new_df
# Out:
#      Post Month variable   value
# 0            12     like    79.0
# 1            12     like   130.0
# 2            12     like    66.0
# 3            12     like  1572.0
# 4            12     like   325.0
# ..          ...      ...     ...
# 495           1     like    53.0
# 496           1     like    53.0
# 497           1     like    93.0
# 498           1     like    91.0
# 499           1     like    91.0
#
# [500 rows x 3 columns]

# %%
df_melted = pd.melt(df,
                    id_vars=['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid'],
                    value_vars=['comment', 'like', 'share'],
                    var_name='Interaction Type',
                    value_name='Interaction Count')

# %%
df_melted
# Out:
#       Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               139441   Photo         2          12             4          3
# 1               139441  Status         2          12             3         10
# 2               139441   Photo         3          12             3          3
# 3               139441   Photo         2          12             2         10
# 4               139441   Photo         2          12             2          3
# ...                ...     ...       ...         ...           ...        ...
# 1495             85093   Photo         3           1             7          2
# 1496             81370   Photo         2           1             5          8
# 1497             81370   Photo         1           1             5          2
# 1498             81370   Photo         3           1             4         11
# 1499             81370   Photo         2           1             4          4
#
# ...
